# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# %cd /content/drive/My\ Drive/Multitask/
# Out:
# /content/drive/My Drive/Multitask

# %%
import model
import tensorflow as tf
# Out:
# <p style="color: red;">
# The default version of TensorFlow in Colab will soon switch to TensorFlow 2.x.<br>
# We recommend you <a href="https://www.tensorflow.org/guide/migrate" target="_blank">upgrade</a> now
# or ensure your notebook will continue to use TensorFlow 1.x via the <code>%tensorflow_version 1.x</code> magic:
# <a href="https://colab.research.google.com/notebooks/tensorflow_version.ipynb" target="_blank">more info</a>.</p>

# %%
session = tf.compat.v1.Session()

# %%
multitask_model = model.Model(session, trainable=True)
# Out:
# WARNING:tensorflow:From /content/drive/My Drive/Multitask/utils.py:48: where (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where
# WARNING:tensorflow:From /content/drive/My Drive/Multitask/utils.py:83: The name tf.nn.max_pool is deprecated. Please use tf.nn.max_pool2d instead.
#
# WARNING:tensorflow:From /content/drive/My Drive/Multitask/utils.py:79: calling dropout (from tensorflow.python.ops.nn_ops) with keep_prob is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `rate` instead of `keep_prob`. Rate should be set to `rate = 1 - keep_prob`.
# ==================================================================
#
# Loading smile image datasets.....
# Done!
# Number of smile train data:  3000
# ==================================================================
#
# Loading age image datasets.....
# Done!
# Number of age train data:  29605
# ==================================================================
#
# Loading gender image datasets.....
# Done!
# Number of gender train data:  29605
# Created model with fresh parameters.

# %%
multitask_model.train()
# Out:
# =======================================================================
# Epoch 1/80:
# smile_loss: 0.13, age_loss: 0.47, gender_loss: 0.19, l2_loss: 0.12, total_loss: 0.91
#
# Smile task train accuracy:  86.59333333333333
# Age task train accuracy:  43.34402972470867
# Gender task train accuracy:  73.00118223273095
# =======================================================================
# Epoch 2/80:
# smile_loss: 0.13, age_loss: 0.47, gender_loss: 0.21, l2_loss: 0.06, total_loss: 0.86
#
# Smile task train accuracy:  93.88
# Age task train accuracy:  43.37442999493329
# Gender task train accuracy:  73.00118223273095
# =======================================================================
# Epoch 3/80:
# smile_loss: 0.12, age_loss: 0.59, gender_loss: 0.17, l2_loss: 0.03, total_loss: 0.92
#
# Smile task train accuracy:  96.28999999999999
# Age task train accuracy:  43.37105218713055
# Gender task train accuracy:  73.00118223273095
# =======================================================================
# Epoch 4/80:
# smile_loss: 0.11, age_loss: 0.40, gender_loss: 0.20, l2_loss: 0.02, total_loss: 0.74
#
# Smile task train accuracy:  97.25
# Age task train accuracy:  43.37105218713055
# Gender task train accuracy:  73.00118223273095
# =======================================================================
# Epoch 5/80:
# smile_loss: 0.12, age_loss: 0.52, gender_loss: 0.14, l2_loss: 0.03, total_loss: 0.81
#
# Smile task train accuracy:  97.20666666666666
# Age task train accuracy:  44.04323593987502
# Gender task train accuracy:  72.99780442492822
# =======================================================================
# Epoch 6/80:
# smile_loss: 0.12, age_loss: 0.46, gender_loss: 0.20, l2_loss: 0.03, total_loss: 0.81
#
# Smile task train accuracy:  94.31
# Age task train accuracy:  47.164330349603105
# Gender task train accuracy:  73.00118223273095
# =======================================================================
# Epoch 7/80:
# smile_loss: 0.10, age_loss: 0.40, gender_loss: 0.20, l2_loss: 0.03, total_loss: 0.74
#
# Smile task train accuracy:  97.03
# Age task train accuracy:  51.19067725046445
# Gender task train accuracy:  73.04171592636379
# =======================================================================
# Epoch 8/80:
# smile_loss: 0.13, age_loss: 0.57, gender_loss: 0.12, l2_loss: 0.04, total_loss: 0.85
#
# Smile task train accuracy:  96.3
# Age task train accuracy:  51.028542475933115
# Gender task train accuracy:  74.53808478297584
# =======================================================================
# Epoch 9/80:
# smile_loss: 0.14, age_loss: 0.46, gender_loss: 0.19, l2_loss: 0.04, total_loss: 0.84
#
# Smile task train accuracy:  96.49333333333333
# Age task train accuracy:  52.214153014693466
# Gender task train accuracy:  74.40297247086642
# =======================================================================
# Epoch 10/80:
# smile_loss: 0.10, age_loss: 0.43, gender_loss: 0.25, l2_loss: 0.05, total_loss: 0.82
#
# Smile task train accuracy:  94.80666666666666
# Age task train accuracy:  50.8866745482182
# Gender task train accuracy:  78.44958621854417
# =======================================================================
# Epoch 11/80:
# smile_loss: 0.10, age_loss: 0.53, gender_loss: 0.21, l2_loss: 0.05, total_loss: 0.89
#
# Smile task train accuracy:  96.09666666666666
# Age task train accuracy:  52.562067218375276
# Gender task train accuracy:  78.4529640263469
# =======================================================================
# Epoch 12/80:
# smile_loss: 0.14, age_loss: 0.40, gender_loss: 0.15, l2_loss: 0.05, total_loss: 0.75
#
# Smile task train accuracy:  95.41333333333334
# Age task train accuracy:  52.187130552271576
# Gender task train accuracy:  83.21229522040196
# =======================================================================
# Epoch 13/80:
# smile_loss: 0.10, age_loss: 0.44, gender_loss: 0.17, l2_loss: 0.05, total_loss: 0.75
#
# Smile task train accuracy:  96.54
# Age task train accuracy:  53.28491808816078
# Gender task train accuracy:  85.29302482688735
# =======================================================================
# Epoch 14/80:
# smile_loss: 0.12, age_loss: 0.42, gender_loss: 0.15, l2_loss: 0.05, total_loss: 0.75
#
# Smile task train accuracy:  96.28333333333333
# Age task train accuracy:  53.21398412430332
# Gender task train accuracy:  85.65107245397738
# =======================================================================
# Epoch 15/80:
# smile_loss: 0.12, age_loss: 0.39, gender_loss: 0.17, l2_loss: 0.05, total_loss: 0.73
#
# Smile task train accuracy:  96.29666666666667
# Age task train accuracy:  53.64634352305354
# Gender task train accuracy:  84.75257557844958
# =======================================================================
# Epoch 16/80:
# smile_loss: 0.10, age_loss: 0.51, gender_loss: 0.11, l2_loss: 0.05, total_loss: 0.77
#
# Smile task train accuracy:  97.10666666666667
# Age task train accuracy:  53.703766255700046
# Gender task train accuracy:  86.42121263300119
# =======================================================================
# Epoch 17/80:
# smile_loss: 0.13, age_loss: 0.53, gender_loss: 0.14, l2_loss: 0.05, total_loss: 0.85
#
# Smile task train accuracy:  97.21
# Age task train accuracy:  54.65630805607161
# Gender task train accuracy:  88.13038338118561
# =======================================================================
# Epoch 18/80:
# smile_loss: 0.11, age_loss: 0.44, gender_loss: 0.16, l2_loss: 0.05, total_loss: 0.76
#
# Smile task train accuracy:  97.33666666666667
# Age task train accuracy:  54.66306367167708
# Gender task train accuracy:  88.99510217868604
# =======================================================================
# Epoch 19/80:
# smile_loss: 0.10, age_loss: 0.30, gender_loss: 0.18, l2_loss: 0.05, total_loss: 0.62
#
# Smile task train accuracy:  97.92
# Age task train accuracy:  54.913021449079544
# Gender task train accuracy:  89.16399256882283
# =======================================================================
# Epoch 20/80:
# smile_loss: 0.12, age_loss: 0.39, gender_loss: 0.14, l2_loss: 0.04, total_loss: 0.69
#
# Smile task train accuracy:  98.03
# Age task train accuracy:  55.66627258908968
# Gender task train accuracy:  90.16044587062996
# =======================================================================
# Epoch 21/80:
# smile_loss: 0.09, age_loss: 0.49, gender_loss: 0.14, l2_loss: 0.04, total_loss: 0.77
#
# Smile task train accuracy:  98.18333333333334
# Age task train accuracy:  56.38236784326972
# Gender task train accuracy:  90.16044587062996
# =======================================================================
# Epoch 22/80:
# smile_loss: 0.10, age_loss: 0.46, gender_loss: 0.14, l2_loss: 0.04, total_loss: 0.74
#
# Smile task train accuracy:  98.15333333333334
# Age task train accuracy:  56.277655801384896
# Gender task train accuracy:  90.48471541969262
# =======================================================================
# Epoch 23/80:
# smile_loss: 0.12, age_loss: 0.36, gender_loss: 0.16, l2_loss: 0.04, total_loss: 0.68
#
# Smile task train accuracy:  98.51666666666667
# Age task train accuracy:  56.58165850363114
# Gender task train accuracy:  91.0184090525249
# =======================================================================
# Epoch 24/80:
# smile_loss: 0.12, age_loss: 0.35, gender_loss: 0.14, l2_loss: 0.04, total_loss: 0.65
#
# Smile task train accuracy:  98.32
# Age task train accuracy:  56.55463604120925
# Gender task train accuracy:  91.15014355683162
# =======================================================================
# Epoch 25/80:
# smile_loss: 0.10, age_loss: 0.43, gender_loss: 0.15, l2_loss: 0.04, total_loss: 0.72
#
# Smile task train accuracy:  98.53666666666666
# Age task train accuracy:  56.49045769295727
# Gender task train accuracy:  90.27191352812025
# =======================================================================
# Epoch 26/80:
# smile_loss: 0.09, age_loss: 0.51, gender_loss: 0.13, l2_loss: 0.04, total_loss: 0.76
#
# Smile task train accuracy:  98.80333333333333
# Age task train accuracy:  57.203175139334576
# Gender task train accuracy:  91.87299442661713
# =======================================================================
# Epoch 27/80:
# smile_loss: 0.12, age_loss: 0.39, gender_loss: 0.13, l2_loss: 0.04, total_loss: 0.68
#
# Smile task train accuracy:  98.79666666666667
# Age task train accuracy:  57.72673534875865
# Gender task train accuracy:  92.80526938017228
# =======================================================================
# Epoch 28/80:
# smile_loss: 0.13, age_loss: 0.49, gender_loss: 0.07, l2_loss: 0.04, total_loss: 0.73
#
# Smile task train accuracy:  98.95
# Age task train accuracy:  58.42256375612228
# Gender task train accuracy:  93.35585205201824
# =======================================================================
# Epoch 29/80:
# smile_loss: 0.12, age_loss: 0.41, gender_loss: 0.15, l2_loss: 0.04, total_loss: 0.72
#
# Smile task train accuracy:  98.90666666666667
# Age task train accuracy:  58.30771829082925
# Gender task train accuracy:  93.57203175139335
# =======================================================================
# Epoch 30/80:
# smile_loss: 0.11, age_loss: 0.46, gender_loss: 0.11, l2_loss: 0.04, total_loss: 0.72
#
# Smile task train accuracy:  98.91
# Age task train accuracy:  58.48336429657153
# Gender task train accuracy:  93.94696841749705
# =======================================================================
# Epoch 31/80:
# smile_loss: 0.13, age_loss: 0.41, gender_loss: 0.11, l2_loss: 0.04, total_loss: 0.69
#
# Smile task train accuracy:  98.99333333333334
# Age task train accuracy:  59.16905928052694
# Gender task train accuracy:  94.19017057929405
# =======================================================================
# Epoch 32/80:
# smile_loss: 0.10, age_loss: 0.47, gender_loss: 0.14, l2_loss: 0.04, total_loss: 0.75
#
# Smile task train accuracy:  99.03666666666666
# Age task train accuracy:  58.868434386083436
# Gender task train accuracy:  94.32190508360074
# =======================================================================
# Epoch 33/80:
# smile_loss: 0.11, age_loss: 0.50, gender_loss: 0.13, l2_loss: 0.04, total_loss: 0.78
#
# Smile task train accuracy:  98.81666666666666
# Age task train accuracy:  59.25350447559534
# Gender task train accuracy:  94.41648370207734
# =======================================================================
# Epoch 34/80:
# smile_loss: 0.11, age_loss: 0.44, gender_loss: 0.11, l2_loss: 0.04, total_loss: 0.70
#
# Smile task train accuracy:  98.72666666666666
# Age task train accuracy:  59.790575916230374
# Gender task train accuracy:  94.8623543320385
# =======================================================================
# Epoch 35/80:
# smile_loss: 0.13, age_loss: 0.53, gender_loss: 0.09, l2_loss: 0.04, total_loss: 0.78
#
# Smile task train accuracy:  99.11
# Age task train accuracy:  59.8311096098632
# Gender task train accuracy:  94.62590778584699
# =======================================================================
# Epoch 36/80:
# smile_loss: 0.12, age_loss: 0.38, gender_loss: 0.13, l2_loss: 0.04, total_loss: 0.66
#
# Smile task train accuracy:  98.66
# Age task train accuracy:  60.29386927883803
# Gender task train accuracy:  95.09542307042729
# =======================================================================
# Epoch 37/80:
# smile_loss: 0.11, age_loss: 0.31, gender_loss: 0.13, l2_loss: 0.04, total_loss: 0.59
#
# Smile task train accuracy:  99.09
# Age task train accuracy:  60.010133423408206
# Gender task train accuracy:  95.30146934639419
# =======================================================================
# Epoch 38/80:
# smile_loss: 0.13, age_loss: 0.34, gender_loss: 0.12, l2_loss: 0.04, total_loss: 0.62
#
# Smile task train accuracy:  99.28666666666666
# Age task train accuracy:  60.52356020942409
# Gender task train accuracy:  95.43320385070089
# =======================================================================
# Epoch 39/80:
# smile_loss: 0.08, age_loss: 0.54, gender_loss: 0.12, l2_loss: 0.04, total_loss: 0.77
#
# Smile task train accuracy:  98.95
# Age task train accuracy:  60.65191690592805
# Gender task train accuracy:  95.21702415132579
# =======================================================================
# Epoch 40/80:
# smile_loss: 0.07, age_loss: 0.48, gender_loss: 0.14, l2_loss: 0.04, total_loss: 0.73
#
# Smile task train accuracy:  99.23666666666666
# Age task train accuracy:  60.98294207059618
# Gender task train accuracy:  95.47711535213647
# =======================================================================
# Epoch 41/80:
# smile_loss: 0.14, age_loss: 0.43, gender_loss: 0.11, l2_loss: 0.04, total_loss: 0.72
#
# Smile task train accuracy:  99.31666666666666
# Age task train accuracy:  60.905252491133254
# Gender task train accuracy:  95.52778246917751
# =======================================================================
# Epoch 42/80:
# smile_loss: 0.12, age_loss: 0.34, gender_loss: 0.13, l2_loss: 0.04, total_loss: 0.63
#
# Smile task train accuracy:  99.21
# Age task train accuracy:  61.23965546360412
# Gender task train accuracy:  95.7709846309745
# =======================================================================
# Epoch 43/80:
# smile_loss: 0.13, age_loss: 0.36, gender_loss: 0.11, l2_loss: 0.04, total_loss: 0.64
#
# Smile task train accuracy:  99.13333333333333
# Age task train accuracy:  61.489613241006595
# Gender task train accuracy:  95.53791589258572
# =======================================================================
# Epoch 44/80:
# smile_loss: 0.10, age_loss: 0.43, gender_loss: 0.13, l2_loss: 0.04, total_loss: 0.69
#
# Smile task train accuracy:  99.36333333333334
# Age task train accuracy:  61.915217024151325
# Gender task train accuracy:  95.72707312953894
# =======================================================================
# Epoch 45/80:
# smile_loss: 0.14, age_loss: 0.39, gender_loss: 0.10, l2_loss: 0.04, total_loss: 0.66
#
# Smile task train accuracy:  99.31333333333333
# Age task train accuracy:  62.19219726397568
# Gender task train accuracy:  96.16956595169735
# =======================================================================
# Epoch 46/80:
# smile_loss: 0.11, age_loss: 0.44, gender_loss: 0.13, l2_loss: 0.04, total_loss: 0.71
#
# Smile task train accuracy:  99.11
# Age task train accuracy:  62.1009964533018
# Gender task train accuracy:  95.95676406012498
# =======================================================================
# Epoch 47/80:
# smile_loss: 0.07, age_loss: 0.48, gender_loss: 0.16, l2_loss: 0.04, total_loss: 0.74
#
# Smile task train accuracy:  99.44333333333333
# Age task train accuracy:  62.263131227833135
# Gender task train accuracy:  96.00405336936329
# =======================================================================
# Epoch 48/80:
# smile_loss: 0.11, age_loss: 0.37, gender_loss: 0.13, l2_loss: 0.04, total_loss: 0.64
#
# Smile task train accuracy:  99.31666666666666
# Age task train accuracy:  62.60091200810673
# Gender task train accuracy:  95.90609694308394
# =======================================================================
# Epoch 49/80:
# smile_loss: 0.11, age_loss: 0.40, gender_loss: 0.12, l2_loss: 0.04, total_loss: 0.67
#
# Smile task train accuracy:  99.39333333333333
# Age task train accuracy:  62.249619996622194
# Gender task train accuracy:  95.9027191352812
# =======================================================================
# Epoch 50/80:
# smile_loss: 0.11, age_loss: 0.45, gender_loss: 0.11, l2_loss: 0.04, total_loss: 0.71
#
# Smile task train accuracy:  99.35000000000001
# Age task train accuracy:  63.20216179699375
# Gender task train accuracy:  96.33170072622868
# =======================================================================
# Epoch 51/80:
# smile_loss: 0.13, age_loss: 0.50, gender_loss: 0.09, l2_loss: 0.04, total_loss: 0.75
#
# Smile task train accuracy:  99.08
# Age task train accuracy:  62.75629116703259
# Gender task train accuracy:  96.12903225806451
# =======================================================================
# Epoch 52/80:
# smile_loss: 0.11, age_loss: 0.35, gender_loss: 0.13, l2_loss: 0.04, total_loss: 0.63
#
# Smile task train accuracy:  99.44333333333333
# Age task train accuracy:  62.90153690255025
# Gender task train accuracy:  95.8655632494511
# =======================================================================
# Epoch 53/80:
# smile_loss: 0.13, age_loss: 0.31, gender_loss: 0.13, l2_loss: 0.04, total_loss: 0.61
#
# Smile task train accuracy:  99.44
# Age task train accuracy:  63.03664921465969
# Gender task train accuracy:  96.47356865394359
# =======================================================================
# Epoch 54/80:
# smile_loss: 0.12, age_loss: 0.38, gender_loss: 0.09, l2_loss: 0.04, total_loss: 0.64
#
# Smile task train accuracy:  99.39666666666666
# Age task train accuracy:  63.165005911163654
# Gender task train accuracy:  96.30805607160953
# =======================================================================
# Epoch 55/80:
# smile_loss: 0.11, age_loss: 0.36, gender_loss: 0.12, l2_loss: 0.04, total_loss: 0.63
#
# Smile task train accuracy:  99.28
# Age task train accuracy:  63.448741766593486
# Gender task train accuracy:  96.04120925519338
# =======================================================================
# Epoch 56/80:
# smile_loss: 0.11, age_loss: 0.43, gender_loss: 0.10, l2_loss: 0.04, total_loss: 0.68
#
# Smile task train accuracy:  99.46333333333334
# Age task train accuracy:  63.65816585036311
# Gender task train accuracy:  96.5681472724202
# =======================================================================
# Epoch 57/80:
# smile_loss: 0.11, age_loss: 0.45, gender_loss: 0.10, l2_loss: 0.04, total_loss: 0.70
#
# Smile task train accuracy:  99.53999999999999
# Age task train accuracy:  63.769633507853406
# Gender task train accuracy:  96.44316838371897
# =======================================================================
# Epoch 58/80:
# smile_loss: 0.12, age_loss: 0.41, gender_loss: 0.12, l2_loss: 0.04, total_loss: 0.69
#
# Smile task train accuracy:  99.51
# Age task train accuracy:  63.44198615098801
# Gender task train accuracy:  96.00405336936329
# =======================================================================
# Epoch 59/80:
# smile_loss: 0.12, age_loss: 0.39, gender_loss: 0.10, l2_loss: 0.04, total_loss: 0.65
#
# Smile task train accuracy:  99.48
# Age task train accuracy:  63.766255700050664
# Gender task train accuracy:  96.26414457017395
# =======================================================================
# Epoch 60/80:
# smile_loss: 0.09, age_loss: 0.54, gender_loss: 0.11, l2_loss: 0.04, total_loss: 0.78
#
# Smile task train accuracy:  99.41333333333333
# Age task train accuracy:  63.793278162472554
# Gender task train accuracy:  96.41952372909981
# =======================================================================
# Epoch 61/80:
# smile_loss: 0.11, age_loss: 0.43, gender_loss: 0.11, l2_loss: 0.04, total_loss: 0.68
#
# Smile task train accuracy:  99.47
# Age task train accuracy:  64.01621347745314
# Gender task train accuracy:  96.6154365816585
# =======================================================================
# Epoch 62/80:
# smile_loss: 0.11, age_loss: 0.41, gender_loss: 0.11, l2_loss: 0.04, total_loss: 0.67
#
# Smile task train accuracy:  99.47333333333333
# Age task train accuracy:  64.11416990373247
# Gender task train accuracy:  96.5681472724202
# =======================================================================
# Epoch 63/80:
# smile_loss: 0.12, age_loss: 0.48, gender_loss: 0.11, l2_loss: 0.04, total_loss: 0.75
#
# Smile task train accuracy:  99.57333333333334
# Age task train accuracy:  64.37426110454315
# Gender task train accuracy:  96.6525924674886
# =======================================================================
# Epoch 64/80:
# smile_loss: 0.10, age_loss: 0.52, gender_loss: 0.10, l2_loss: 0.04, total_loss: 0.76
#
# Smile task train accuracy:  99.42999999999999
# Age task train accuracy:  63.75274446883973
# Gender task train accuracy:  96.6053031582503
# =======================================================================
# Epoch 65/80:
# smile_loss: 0.10, age_loss: 0.41, gender_loss: 0.12, l2_loss: 0.04, total_loss: 0.66
#
# Smile task train accuracy:  99.60333333333334
# Age task train accuracy:  65.03293362607667
# Gender task train accuracy:  96.7944603952035
# =======================================================================
# Epoch 66/80:
# smile_loss: 0.12, age_loss: 0.38, gender_loss: 0.12, l2_loss: 0.04, total_loss: 0.66
#
# Smile task train accuracy:  99.51
# Age task train accuracy:  64.99577774024658
# Gender task train accuracy:  96.737037662557
# =======================================================================
# Epoch 67/80:
# smile_loss: 0.13, age_loss: 0.43, gender_loss: 0.10, l2_loss: 0.04, total_loss: 0.70
#
# Smile task train accuracy:  99.59333333333333
# Age task train accuracy:  64.8201317345043
# Gender task train accuracy:  96.65934808309407
# =======================================================================
# Epoch 68/80:
# smile_loss: 0.13, age_loss: 0.45, gender_loss: 0.09, l2_loss: 0.04, total_loss: 0.70
#
# Smile task train accuracy:  99.56666666666666
# Age task train accuracy:  64.88431008275629
# Gender task train accuracy:  96.88903901368012
# =======================================================================
# Epoch 69/80:
# smile_loss: 0.10, age_loss: 0.43, gender_loss: 0.14, l2_loss: 0.04, total_loss: 0.71
#
# Smile task train accuracy:  99.56666666666666
# Age task train accuracy:  65.35720317513933
# Gender task train accuracy:  96.66610369869954
# =======================================================================
# Epoch 70/80:
# smile_loss: 0.09, age_loss: 0.54, gender_loss: 0.09, l2_loss: 0.04, total_loss: 0.77
#
# Smile task train accuracy:  99.56
# Age task train accuracy:  65.51933794967067
# Gender task train accuracy:  96.76743793278162
# =======================================================================
# Epoch 71/80:
# smile_loss: 0.10, age_loss: 0.42, gender_loss: 0.12, l2_loss: 0.04, total_loss: 0.67
#
# Smile task train accuracy:  99.42999999999999
# Age task train accuracy:  65.32680290491471
# Gender task train accuracy:  96.84512751224456
# =======================================================================
# Epoch 72/80:
# smile_loss: 0.15, age_loss: 0.36, gender_loss: 0.10, l2_loss: 0.04, total_loss: 0.65
#
# Smile task train accuracy:  99.51666666666667
# Age task train accuracy:  64.86742104374261
# Gender task train accuracy:  96.67961492991049
# =======================================================================
# Epoch 73/80:
# smile_loss: 0.11, age_loss: 0.50, gender_loss: 0.08, l2_loss: 0.04, total_loss: 0.73
#
# Smile task train accuracy:  99.59666666666666
# Age task train accuracy:  65.39773686877217
# Gender task train accuracy:  97.00726228677588
# =======================================================================
# Epoch 74/80:
# smile_loss: 0.12, age_loss: 0.38, gender_loss: 0.10, l2_loss: 0.04, total_loss: 0.64
#
# Smile task train accuracy:  99.56666666666666
# Age task train accuracy:  65.09711197432866
# Gender task train accuracy:  96.78094916399257
# =======================================================================
# Epoch 75/80:
# smile_loss: 0.12, age_loss: 0.41, gender_loss: 0.09, l2_loss: 0.04, total_loss: 0.66
#
# Smile task train accuracy:  99.22666666666666
# Age task train accuracy:  64.69853065360581
# Gender task train accuracy:  96.55801384901199
# =======================================================================
# Epoch 76/80:
# smile_loss: 0.11, age_loss: 0.42, gender_loss: 0.11, l2_loss: 0.04, total_loss: 0.69
#
# Smile task train accuracy:  99.27333333333334
# Age task train accuracy:  64.70528626921129
# Gender task train accuracy:  96.63232562067219
# =======================================================================
# Epoch 77/80:
# smile_loss: 0.13, age_loss: 0.42, gender_loss: 0.12, l2_loss: 0.04, total_loss: 0.71
#
# Smile task train accuracy:  99.59333333333333
# Age task train accuracy:  65.50244891065698
# Gender task train accuracy:  97.05117378821146
# =======================================================================
# Epoch 78/80:
# smile_loss: 0.12, age_loss: 0.42, gender_loss: 0.11, l2_loss: 0.04, total_loss: 0.68
#
# Smile task train accuracy:  99.61
# Age task train accuracy:  65.74227326465125
# Gender task train accuracy:  96.91606147610202
# =======================================================================
# Epoch 79/80:
# smile_loss: 0.11, age_loss: 0.49, gender_loss: 0.09, l2_loss: 0.04, total_loss: 0.74
#
# Smile task train accuracy:  99.63
# Age task train accuracy:  65.7760513426786
# Gender task train accuracy:  96.95997297753757
# =======================================================================
# Epoch 80/80:
# smile_loss: 0.12, age_loss: 0.36, gender_loss: 0.14, l2_loss: 0.04, total_loss: 0.66
#
# Smile task train accuracy:  99.53
# Age task train accuracy:  66.05640939030569
# Gender task train accuracy:  97.01401790238135
